# %% [markdown]
# # create model/loss fn/optimizer from HP tuning

# %%
# load best hyperparameters
import ast

with open('../results/resnet_tune/best_params.txt', 'r') as f:
    best_params = ast.literal_eval(f.read())

best_params
# Out:
# {'undersample': False,
#  'lr': 0.0002827499994577573,
#  'dropout1': 0.45488846901588875,
#  'dropout2': 0.4473711981698735,
#  'hidden1': 1536,
#  'hidden2': 640,
#  'num_fc_layers': 3,
#  'hidden3': 320,
#  'weighted_loss': False,
#  'unfreeze_layer4': True}

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torchvision import models
from utils import DRDataset
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from imblearn.under_sampling import RandomUnderSampler

NUM_CLASSES = 5
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyperparameters
use_undersampling = best_params['undersample']
lr = best_params['lr']
dropout1 = best_params['dropout1']
dropout2 = best_params['dropout2']
hidden1 = best_params['hidden1']
hidden2 = best_params['hidden2']
num_fc_layers = best_params['num_fc_layers']
hidden3 = best_params['hidden3'] if 'hidden3' in best_params else None
weighted_loss = best_params['weighted_loss']
unfreeze_layer4 = best_params['unfreeze_layer4']

# Model
model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
model.requires_grad_(False)
if unfreeze_layer4:
    for param in model.layer4.parameters():
        param.requires_grad = True

fc_layers = [
    nn.Linear(model.fc.in_features, hidden1),
    nn.ReLU(),
    nn.Dropout(p=dropout1)
]
if num_fc_layers >= 2:
    fc_layers.extend([
        nn.Linear(hidden1, hidden2),
        nn.ReLU(),
        nn.Dropout(p=dropout2)
    ])
if num_fc_layers == 3:
    fc_layers.extend([
        nn.Linear(hidden2, hidden3),
        nn.ReLU(),
        nn.Dropout(p=0.25),
        nn.Linear(hidden3, NUM_CLASSES)
    ])
else:
    fc_layers.append(nn.Linear(hidden2 if num_fc_layers == 2 else hidden1, NUM_CLASSES))

model.fc = nn.Sequential(*fc_layers)

# %% [markdown]
# # train

# %% [raw]
# # build dataset
#
# TODO:
# * train on whole dataset (preprocess images first since it will take too long) --> DONE
# * remove random split and split data beforehand --> split data so as to counteract class imbalance. Moderate imbalance so use SMOTE (oversampling)

# %%
import os
import pandas as pd
import torch
from torchvision import models
from utils import DRDataset
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE, RandomOverSampler
import numpy as np

DESC = 'resnet_final'
if not os.path.exists(f'../results/{DESC}'):
    os.makedirs(f'../results/{DESC}')
    
#load labels
labels = pd.read_csv('../data/trainLabels.csv')

NUM_CLASSES = len(labels['level'].unique())
LABELS_MAP = ['0-No DR', '1-Mild', '2-Moderate', '3-Severe', '4-Proliferative DR']
BATCH_SIZE = 32

# load baseline train/test data
meta = torch.load('../results/resnet/metadata.pth', weights_only=False)
train_data = meta['train_data']
val_data = meta['val_data']
test_data = meta['test_data']

#Create DataLoaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

#dataset size checks
train_N = len(train_loader.dataset)
val_N = len(val_loader.dataset)
test_N = len(test_loader.dataset)

train_N, val_N, test_N
# Out:
# (24588, 3512, 7026)

# %% [raw]
# # build model
#
# TODO:
# * more dense layers?
# * different backbone (other than resnet)? Can change this for the project to include a hybrid CNN/Transformer model depending on if we want or need greater generalization, etc.
# * can create weighted loss function
# * can add class weights if SMOTE doesn't yield good results

# %%
# load resnet
resnet = model

# print model summary
from torchinfo import summary
summary(resnet, input_size=next(resnet.parameters()).size())
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [64, 5]                   --
# ├─Conv2d: 1-1                            [64, 64, 4, 4]            (9,408)
# ├─BatchNorm2d: 1-2                       [64, 64, 4, 4]            (128)
# ├─ReLU: 1-3                              [64, 64, 4, 4]            --
# ├─MaxPool2d: 1-4                         [64, 64, 2, 2]            --
# ├─Sequential: 1-5                        [64, 256, 2, 2]           --
# │    └─Bottleneck: 2-1                   [64, 256, 2, 2]           --
# │    │    └─Conv2d: 3-1                  [64, 64, 2, 2]            (4,096)
# │    │    └─BatchNorm2d: 3-2             [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-3                    [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-4                  [64, 64, 2, 2]            (36,864)
# │    │    └─BatchNorm2d: 3-5             [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-6                    [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-7                  [64, 256, 2, 2]           (16,384)
# │    │    └─BatchNorm2d: 3-8             [64, 256, 2, 2]           (512)
# │    │    └─Sequential: 3-9              [64, 256, 2, 2]           (16,896)
# │    │    └─ReLU: 3-10                   [64, 256, 2, 2]           --
# │    └─Bottleneck: 2-2                   [64, 256, 2, 2]           --
# │    │    └─Conv2d: 3-11                 [64, 64, 2, 2]            (16,384)
# │    │    └─BatchNorm2d: 3-12            [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-13                   [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-14                 [64, 64, 2, 2]            (36,864)
# │    │    └─BatchNorm2d: 3-15            [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-16                   [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-17                 [64, 256, 2, 2]           (16,384)
# │    │    └─BatchNorm2d: 3-18            [64, 256, 2, 2]           (512)
# │    │    └─ReLU: 3-19                   [64, 256, 2, 2]           --
# │    └─Bottleneck: 2-3                   [64, 256, 2, 2]           --
# │    │    └─Conv2d: 3-20                 [64, 64, 2, 2]            (16,384)
# │    │    └─BatchNorm2d: 3-21            [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-22                   [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-23                 [64, 64, 2, 2]            (36,864)
# │    │    └─BatchNorm2d: 3-24            [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-25                   [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-26                 [64, 256, 2, 2]           (16,384)
# │    │    └─BatchNorm2d: 3-27            [64, 256, 2, 2]           (512)
# │    │    └─ReLU: 3-28                   [64, 256, 2, 2]           --
# ├─Sequential: 1-6                        [64, 512, 1, 1]           --
# │    └─Bottleneck: 2-4                   [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-29                 [64, 128, 2, 2]           (32,768)
# │    │    └─BatchNorm2d: 3-30            [64, 128, 2, 2]           (256)
# │    │    └─ReLU: 3-31                   [64, 128, 2, 2]           --
# │    │    └─Conv2d: 3-32                 [64, 128, 1, 1]           (147,456)
# │    │    └─BatchNorm2d: 3-33            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-34                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-35                 [64, 512, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-36            [64, 512, 1, 1]           (1,024)
# │    │    └─Sequential: 3-37             [64, 512, 1, 1]           (132,096)
# │    │    └─ReLU: 3-38                   [64, 512, 1, 1]           --
# │    └─Bottleneck: 2-5                   [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-39                 [64, 128, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-40            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-41                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-42                 [64, 128, 1, 1]           (147,456)
# │    │    └─BatchNorm2d: 3-43            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-44                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-45                 [64, 512, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-46            [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-47                   [64, 512, 1, 1]           --
# │    └─Bottleneck: 2-6                   [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-48                 [64, 128, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-49            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-50                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-51                 [64, 128, 1, 1]           (147,456)
# │    │    └─BatchNorm2d: 3-52            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-53                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-54                 [64, 512, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-55            [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-56                   [64, 512, 1, 1]           --
# │    └─Bottleneck: 2-7                   [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-57                 [64, 128, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-58            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-59                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-60                 [64, 128, 1, 1]           (147,456)
# │    │    └─BatchNorm2d: 3-61            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-62                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-63                 [64, 512, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-64            [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-65                   [64, 512, 1, 1]           --
# ├─Sequential: 1-7                        [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-8                   [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-66                 [64, 256, 1, 1]           (131,072)
# │    │    └─BatchNorm2d: 3-67            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-68                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-69                 [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-70            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-71                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-72                 [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-73            [64, 1024, 1, 1]          (2,048)
# │    │    └─Sequential: 3-74             [64, 1024, 1, 1]          (526,336)
# │    │    └─ReLU: 3-75                   [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-9                   [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-76                 [64, 256, 1, 1]           (262,144)
# │    │    └─BatchNorm2d: 3-77            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-78                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-79                 [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-80            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-81                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-82                 [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-83            [64, 1024, 1, 1]          (2,048)
# │    │    └─ReLU: 3-84                   [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-10                  [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-85                 [64, 256, 1, 1]           (262,144)
# │    │    └─BatchNorm2d: 3-86            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-87                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-88                 [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-89            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-90                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-91                 [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-92            [64, 1024, 1, 1]          (2,048)
# │    │    └─ReLU: 3-93                   [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-11                  [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-94                 [64, 256, 1, 1]           (262,144)
# │    │    └─BatchNorm2d: 3-95            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-96                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-97                 [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-98            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-99                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-100                [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-101           [64, 1024, 1, 1]          (2,048)
# │    │    └─ReLU: 3-102                  [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-12                  [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-103                [64, 256, 1, 1]           (262,144)
# │    │    └─BatchNorm2d: 3-104           [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-105                  [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-106                [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-107           [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-108                  [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-109                [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-110           [64, 1024, 1, 1]          (2,048)
# │    │    └─ReLU: 3-111                  [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-13                  [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-112                [64, 256, 1, 1]           (262,144)
# │    │    └─BatchNorm2d: 3-113           [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-114                  [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-115                [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-116           [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-117                  [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-118                [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-119           [64, 1024, 1, 1]          (2,048)
# │    │    └─ReLU: 3-120                  [64, 1024, 1, 1]          --
# ├─Sequential: 1-8                        [64, 2048, 1, 1]          --
# │    └─Bottleneck: 2-14                  [64, 2048, 1, 1]          --
# │    │    └─Conv2d: 3-121                [64, 512, 1, 1]           524,288
# │    │    └─BatchNorm2d: 3-122           [64, 512, 1, 1]           1,024
# │    │    └─ReLU: 3-123                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-124                [64, 512, 1, 1]           2,359,296
# │    │    └─BatchNorm2d: 3-125           [64, 512, 1, 1]           1,024
# │    │    └─ReLU: 3-126                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-127                [64, 2048, 1, 1]          1,048,576
# │    │    └─BatchNorm2d: 3-128           [64, 2048, 1, 1]          4,096
# │    │    └─Sequential: 3-129            [64, 2048, 1, 1]          2,101,248
# │    │    └─ReLU: 3-130                  [64, 2048, 1, 1]          --
# │    └─Bottleneck: 2-15                  [64, 2048, 1, 1]          --
# │    │    └─Conv2d: 3-131                [64, 512, 1, 1]           1,048,576
# │    │    └─BatchNorm2d: 3-132           [64, 512, 1, 1]           1,024
# │    │    └─ReLU: 3-133                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-134                [64, 512, 1, 1]           2,359,296
# │    │    └─BatchNorm2d: 3-135           [64, 512, 1, 1]           1,024
# │    │    └─ReLU: 3-136                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-137                [64, 2048, 1, 1]          1,048,576
# │    │    └─BatchNorm2d: 3-138           [64, 2048, 1, 1]          4,096
# │    │    └─ReLU: 3-139                  [64, 2048, 1, 1]          --
# │    └─Bottleneck: 2-16                  [64, 2048, 1, 1]          --
# │    │    └─Conv2d: 3-140                [64, 512, 1, 1]           1,048,576
# │    │    └─BatchNorm2d: 3-141           [64, 512, 1, 1]           1,024
# │    │    └─ReLU: 3-142                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-143                [64, 512, 1, 1]           2,359,296
# │    │    └─BatchNorm2d: 3-144           [64, 512, 1, 1]           1,024
# │    │    └─ReLU: 3-145                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-146                [64, 2048, 1, 1]          1,048,576
# │    │    └─BatchNorm2d: 3-147           [64, 2048, 1, 1]          4,096
# │    │    └─ReLU: 3-148                  [64, 2048, 1, 1]          --
# ├─AdaptiveAvgPool2d: 1-9                 [64, 2048, 1, 1]          --
# ├─Sequential: 1-10                       [64, 5]                   --
# │    └─Linear: 2-17                      [64, 1536]                3,147,264
# │    └─ReLU: 2-18                        [64, 1536]                --
# │    └─Dropout: 2-19                     [64, 1536]                --
# │    └─Linear: 2-20                      [64, 640]                 983,680
# │    └─ReLU: 2-21                        [64, 640]                 --
# │    └─Dropout: 2-22                     [64, 640]                 --
# │    └─Linear: 2-23                      [64, 320]                 205,120
# │    └─ReLU: 2-24                        [64, 320]                 --
# │    └─Dropout: 2-25                     [64, 320]                 --
# │    └─Linear: 2-26                      [64, 5]                   1,605
# ==========================================================================================
# Total params: 27,845,701
# Trainable params: 19,302,405
# Non-trainable params: 8,543,296
# Total mult-adds (Units.GIGABYTES): 1.84
# ==========================================================================================
# Input size (MB): 0.04
# Forward/backward pass size (MB): 34.18
# Params size (MB): 111.38
# Estimated Total Size (MB): 145.60
# ==========================================================================================

# %% [raw]
# # train/val/test
#
# TODO:
# * early stopping?
# * potentially modify loss function after assessing baseline

# %%
# compile model
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
resnet.to(DEVICE)
# Loss
if weighted_loss:
    class_weights = compute_class_weight('balanced', classes=np.arange(NUM_CLASSES), y=[int(i[1]) for i in train_data])
    loss_fn = nn.CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32).to(DEVICE))
else:
    loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# train
EPOCHS = 100
train_losses = []
val_losses = []
train_accs = []
val_accs = []
best_val_loss = torch.inf
for epoch in range(EPOCHS):
    # train
    resnet.train()
    running_loss = 0.0
    running_correct = 0
    for i, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = resnet(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        running_correct += (torch.softmax(outputs, dim=1).argmax(dim=1) == labels).sum().item()

    # val
    resnet.eval()
    running_vloss = 0.0
    running_vcorrect = 0
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_loader):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

            outputs = resnet(inputs)
            vloss = loss_fn(outputs, labels)
            running_vloss += vloss.item()
            running_vcorrect += (torch.softmax(outputs, dim=1).argmax(dim=1) == labels).sum().item()

    print(f"Epoch {epoch+1}/{EPOCHS}\t" +
          f"Train Loss: {running_loss/train_N:.4f} | Train Acc: {running_correct/train_N:.4f} | " +
          f"Val Loss: {running_vloss/val_N:.4f} | Val Acc: {running_vcorrect/val_N:.4f}")

    train_losses.append(running_loss/train_N)
    val_losses.append(running_vloss/val_N)
    train_accs.append(running_correct/train_N)
    val_accs.append(running_vcorrect/val_N)

    # save best model
    if running_vloss < best_val_loss:
        best_val_loss = running_vloss
        torch.save(resnet, f'../results/{DESC}/model.pth')

# evaluate
# load best model
resnet = torch.load(f'../results/{DESC}/model.pth', weights_only=False).to(DEVICE)
resnet.eval()
correct = 0
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_loader):
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        outputs = resnet(inputs)
        correct += (torch.softmax(outputs, dim=1).argmax(dim=1) == labels).sum().item()
print()
print(f'Test Accuracy: {correct/test_N:.4f}')
# Out:
# Epoch 1/100	Train Loss: 0.0236 | Train Acc: 0.7532 | Val Loss: 0.0216 | Val Acc: 0.7662
# Epoch 2/100	Train Loss: 0.0191 | Train Acc: 0.7904 | Val Loss: 0.0219 | Val Acc: 0.7580
# Epoch 3/100	Train Loss: 0.0145 | Train Acc: 0.8363 | Val Loss: 0.0215 | Val Acc: 0.7702
# Epoch 4/100	Train Loss: 0.0094 | Train Acc: 0.8928 | Val Loss: 0.0281 | Val Acc: 0.7397
# Epoch 5/100	Train Loss: 0.0051 | Train Acc: 0.9433 | Val Loss: 0.0369 | Val Acc: 0.7674
# Epoch 6/100	Train Loss: 0.0033 | Train Acc: 0.9646 | Val Loss: 0.0320 | Val Acc: 0.7628
# Epoch 7/100	Train Loss: 0.0024 | Train Acc: 0.9745 | Val Loss: 0.0353 | Val Acc: 0.7548
# Epoch 8/100	Train Loss: 0.0020 | Train Acc: 0.9791 | Val Loss: 0.0416 | Val Acc: 0.7728
# Epoch 9/100	Train Loss: 0.0017 | Train Acc: 0.9811 | Val Loss: 0.0459 | Val Acc: 0.7742
# Epoch 10/100	Train Loss: 0.0017 | Train Acc: 0.9808 | Val Loss: 0.0436 | Val Acc: 0.7677
# Epoch 11/100	Train Loss: 0.0014 | Train Acc: 0.9858 | Val Loss: 0.0489 | Val Acc: 0.7514
# Epoch 12/100	Train Loss: 0.0016 | Train Acc: 0.9835 | Val Loss: 0.0447 | Val Acc: 0.7759
# Epoch 13/100	Train Loss: 0.0012 | Train Acc: 0.9868 | Val Loss: 0.0520 | Val Acc: 0.7614
# Epoch 14/100	Train Loss: 0.0013 | Train Acc: 0.9864 | Val Loss: 0.0561 | Val Acc: 0.7657
# Epoch 15/100	Train Loss: 0.0012 | Train Acc: 0.9874 | Val Loss: 0.0520 | Val Acc: 0.7426
# Epoch 16/100	Train Loss: 0.0011 | Train Acc: 0.9882 | Val Loss: 0.0486 | Val Acc: 0.7679
# Epoch 17/100	Train Loss: 0.0011 | Train Acc: 0.9884 | Val Loss: 0.0688 | Val Acc: 0.7682
# Epoch 18/100	Train Loss: 0.0010 | Train Acc: 0.9898 | Val Loss: 0.0478 | Val Acc: 0.7511
# Epoch 19/100	Train Loss: 0.0012 | Train Acc: 0.9878 | Val Loss: 0.0426 | Val Acc: 0.7611
# Epoch 20/100	Train Loss: 0.0010 | Train Acc: 0.9893 | Val Loss: 0.0531 | Val Acc: 0.7594
# Epoch 21/100	Train Loss: 0.0010 | Train Acc: 0.9908 | Val Loss: 0.0577 | Val Acc: 0.7617
# Epoch 22/100	Train Loss: 0.0009 | Train Acc: 0.9905 | Val Loss: 0.0565 | Val Acc: 0.7751
# Epoch 23/100	Train Loss: 0.0009 | Train Acc: 0.9913 | Val Loss: 0.0520 | Val Acc: 0.7620
# Epoch 24/100	Train Loss: 0.0009 | Train Acc: 0.9904 | Val Loss: 0.0538 | Val Acc: 0.7546
# Epoch 25/100	Train Loss: 0.0009 | Train Acc: 0.9906 | Val Loss: 0.0529 | Val Acc: 0.7580
# Epoch 26/100	Train Loss: 0.0008 | Train Acc: 0.9910 | Val Loss: 0.0572 | Val Acc: 0.7665
# Epoch 27/100	Train Loss: 0.0008 | Train Acc: 0.9918 | Val Loss: 0.0527 | Val Acc: 0.7634
# Epoch 28/100	Train Loss: 0.0008 | Train Acc: 0.9926 | Val Loss: 0.0496 | Val Acc: 0.7571
# Epoch 29/100	Train Loss: 0.0008 | Train Acc: 0.9922 | Val Loss: 0.0582 | Val Acc: 0.7611
# Epoch 30/100	Train Loss: 0.0009 | Train Acc: 0.9916 | Val Loss: 0.0422 | Val Acc: 0.7489
# Epoch 31/100	Train Loss: 0.0007 | Train Acc: 0.9928 | Val Loss: 0.0714 | Val Acc: 0.7779
# Epoch 32/100	Train Loss: 0.0007 | Train Acc: 0.9929 | Val Loss: 0.0574 | Val Acc: 0.7765
# Epoch 33/100	Train Loss: 0.0007 | Train Acc: 0.9926 | Val Loss: 0.0584 | Val Acc: 0.7594
# Epoch 34/100	Train Loss: 0.0007 | Train Acc: 0.9928 | Val Loss: 0.0582 | Val Acc: 0.7716
# Epoch 35/100	Train Loss: 0.0007 | Train Acc: 0.9933 | Val Loss: 0.0614 | Val Acc: 0.7637
# Epoch 36/100	Train Loss: 0.0008 | Train Acc: 0.9926 | Val Loss: 0.0559 | Val Acc: 0.7614
# Epoch 37/100	Train Loss: 0.0007 | Train Acc: 0.9926 | Val Loss: 0.0596 | Val Acc: 0.7645
# Epoch 38/100	Train Loss: 0.0006 | Train Acc: 0.9939 | Val Loss: 0.0648 | Val Acc: 0.7645
# Epoch 39/100	Train Loss: 0.0005 | Train Acc: 0.9946 | Val Loss: 0.0695 | Val Acc: 0.7634
# Epoch 40/100	Train Loss: 0.0006 | Train Acc: 0.9937 | Val Loss: 0.0665 | Val Acc: 0.7568
# Epoch 41/100	Train Loss: 0.0007 | Train Acc: 0.9929 | Val Loss: 0.0678 | Val Acc: 0.7625
# Epoch 42/100	Train Loss: 0.0010 | Train Acc: 0.9911 | Val Loss: 0.0659 | Val Acc: 0.7802
# Epoch 43/100	Train Loss: 0.0005 | Train Acc: 0.9950 | Val Loss: 0.0685 | Val Acc: 0.7682
# Epoch 44/100	Train Loss: 0.0005 | Train Acc: 0.9949 | Val Loss: 0.0748 | Val Acc: 0.7742
# Epoch 45/100	Train Loss: 0.0006 | Train Acc: 0.9948 | Val Loss: 0.0587 | Val Acc: 0.7682
# Epoch 46/100	Train Loss: 0.0007 | Train Acc: 0.9935 | Val Loss: 0.0728 | Val Acc: 0.7702
# Epoch 47/100	Train Loss: 0.0006 | Train Acc: 0.9942 | Val Loss: 0.0698 | Val Acc: 0.7674
# Epoch 48/100	Train Loss: 0.0006 | Train Acc: 0.9943 | Val Loss: 0.0635 | Val Acc: 0.7494
# Epoch 49/100	Train Loss: 0.0005 | Train Acc: 0.9954 | Val Loss: 0.0633 | Val Acc: 0.7446
# Epoch 50/100	Train Loss: 0.0006 | Train Acc: 0.9948 | Val Loss: 0.0771 | Val Acc: 0.7714
# Epoch 51/100	Train Loss: 0.0006 | Train Acc: 0.9943 | Val Loss: 0.0885 | Val Acc: 0.7708
# Epoch 52/100	Train Loss: 0.0007 | Train Acc: 0.9939 | Val Loss: 0.0693 | Val Acc: 0.7640
# Epoch 53/100	Train Loss: 0.0006 | Train Acc: 0.9942 | Val Loss: 0.0698 | Val Acc: 0.7588
# Epoch 54/100	Train Loss: 0.0007 | Train Acc: 0.9942 | Val Loss: 0.0804 | Val Acc: 0.7702
# Epoch 55/100	Train Loss: 0.0005 | Train Acc: 0.9947 | Val Loss: 0.0742 | Val Acc: 0.7523
# Epoch 56/100	Train Loss: 0.0005 | Train Acc: 0.9956 | Val Loss: 0.0731 | Val Acc: 0.7657
# Epoch 57/100	Train Loss: 0.0004 | Train Acc: 0.9961 | Val Loss: 0.0711 | Val Acc: 0.7617
# Epoch 58/100	Train Loss: 0.0004 | Train Acc: 0.9960 | Val Loss: 0.0719 | Val Acc: 0.7654
# Epoch 59/100	Train Loss: 0.0005 | Train Acc: 0.9952 | Val Loss: 0.0874 | Val Acc: 0.7608
# Epoch 60/100	Train Loss: 0.0005 | Train Acc: 0.9950 | Val Loss: 0.0772 | Val Acc: 0.7662
# Epoch 61/100	Train Loss: 0.0005 | Train Acc: 0.9949 | Val Loss: 0.0694 | Val Acc: 0.7563
# Epoch 62/100	Train Loss: 0.0005 | Train Acc: 0.9956 | Val Loss: 0.0750 | Val Acc: 0.7608
# Epoch 63/100	Train Loss: 0.0003 | Train Acc: 0.9965 | Val Loss: 0.0926 | Val Acc: 0.7742
# Epoch 64/100	Train Loss: 0.0004 | Train Acc: 0.9952 | Val Loss: 0.0814 | Val Acc: 0.7731
# Epoch 65/100	Train Loss: 0.0005 | Train Acc: 0.9946 | Val Loss: 0.0616 | Val Acc: 0.7642
# Epoch 66/100	Train Loss: 0.0005 | Train Acc: 0.9949 | Val Loss: 0.0696 | Val Acc: 0.7634
# Epoch 67/100	Train Loss: 0.0005 | Train Acc: 0.9952 | Val Loss: 0.0719 | Val Acc: 0.7742
# Epoch 68/100	Train Loss: 0.0004 | Train Acc: 0.9963 | Val Loss: 0.0965 | Val Acc: 0.7699
# Epoch 69/100	Train Loss: 0.0005 | Train Acc: 0.9950 | Val Loss: 0.0744 | Val Acc: 0.7696
# Epoch 70/100	Train Loss: 0.0005 | Train Acc: 0.9956 | Val Loss: 0.0771 | Val Acc: 0.7679
# Epoch 71/100	Train Loss: 0.0004 | Train Acc: 0.9966 | Val Loss: 0.0800 | Val Acc: 0.7577
# Epoch 72/100	Train Loss: 0.0005 | Train Acc: 0.9955 | Val Loss: 0.0731 | Val Acc: 0.7568
# Epoch 73/100	Train Loss: 0.0003 | Train Acc: 0.9964 | Val Loss: 0.0932 | Val Acc: 0.7674
# Epoch 74/100	Train Loss: 0.0004 | Train Acc: 0.9958 | Val Loss: 0.0763 | Val Acc: 0.7591
# Epoch 75/100	Train Loss: 0.0004 | Train Acc: 0.9969 | Val Loss: 0.0735 | Val Acc: 0.7560
# Epoch 76/100	Train Loss: 0.0004 | Train Acc: 0.9958 | Val Loss: 0.0748 | Val Acc: 0.7568
# Epoch 77/100	Train Loss: 0.0003 | Train Acc: 0.9972 | Val Loss: 0.1027 | Val Acc: 0.7679
# Epoch 78/100	Train Loss: 0.0005 | Train Acc: 0.9965 | Val Loss: 0.0840 | Val Acc: 0.7708
# Epoch 79/100	Train Loss: 0.0005 | Train Acc: 0.9951 | Val Loss: 0.0849 | Val Acc: 0.7708
# Epoch 80/100	Train Loss: 0.0005 | Train Acc: 0.9954 | Val Loss: 0.0790 | Val Acc: 0.7611
# Epoch 81/100	Train Loss: 0.0005 | Train Acc: 0.9963 | Val Loss: 0.0660 | Val Acc: 0.7543
# Epoch 82/100	Train Loss: 0.0004 | Train Acc: 0.9963 | Val Loss: 0.0661 | Val Acc: 0.7440
# Epoch 83/100	Train Loss: 0.0004 | Train Acc: 0.9962 | Val Loss: 0.0813 | Val Acc: 0.7642
# Epoch 84/100	Train Loss: 0.0004 | Train Acc: 0.9969 | Val Loss: 0.0943 | Val Acc: 0.7736
# Epoch 85/100	Train Loss: 0.0003 | Train Acc: 0.9971 | Val Loss: 0.0897 | Val Acc: 0.7631
# Epoch 86/100	Train Loss: 0.0004 | Train Acc: 0.9966 | Val Loss: 0.0793 | Val Acc: 0.7677
# Epoch 87/100	Train Loss: 0.0004 | Train Acc: 0.9957 | Val Loss: 0.0824 | Val Acc: 0.7600
# Epoch 88/100	Train Loss: 0.0003 | Train Acc: 0.9970 | Val Loss: 0.0727 | Val Acc: 0.7691
# Epoch 89/100	Train Loss: 0.0004 | Train Acc: 0.9969 | Val Loss: 0.1003 | Val Acc: 0.7742
# Epoch 90/100	Train Loss: 0.0004 | Train Acc: 0.9967 | Val Loss: 0.0994 | Val Acc: 0.7699
# Epoch 91/100	Train Loss: 0.0005 | Train Acc: 0.9956 | Val Loss: 0.0817 | Val Acc: 0.7631
# Epoch 92/100	Train Loss: 0.0003 | Train Acc: 0.9973 | Val Loss: 0.0843 | Val Acc: 0.7625
# Epoch 93/100	Train Loss: 0.0004 | Train Acc: 0.9966 | Val Loss: 0.0870 | Val Acc: 0.7597
# Epoch 94/100	Train Loss: 0.0005 | Train Acc: 0.9956 | Val Loss: 0.0786 | Val Acc: 0.7520
# Epoch 95/100	Train Loss: 0.0003 | Train Acc: 0.9968 | Val Loss: 0.0798 | Val Acc: 0.7600
# Epoch 96/100	Train Loss: 0.0003 | Train Acc: 0.9973 | Val Loss: 0.0738 | Val Acc: 0.7662
# Epoch 97/100	Train Loss: 0.0004 | Train Acc: 0.9963 | Val Loss: 0.0880 | Val Acc: 0.7696
# Epoch 98/100	Train Loss: 0.0003 | Train Acc: 0.9968 | Val Loss: 0.0783 | Val Acc: 0.7617
# Epoch 99/100	Train Loss: 0.0003 | Train Acc: 0.9974 | Val Loss: 0.0902 | Val Acc: 0.7605
# Epoch 100/100	Train Loss: 0.0004 | Train Acc: 0.9965 | Val Loss: 0.0814 | Val Acc: 0.7719
#
# Test Accuracy: 0.7690

# %%
# save datasets, optimizer state, and metrics to metadata file
torch.save({'train_data': train_data,
            'val_data': val_data,
            'test_data': test_data,
            'optimizer_state': optimizer.state_dict(),
            'metrics': pd.DataFrame({'train_loss': train_losses,
                                     'val_loss': val_losses,
                                     'train_acc': train_accs,
                                     'val_acc': val_accs})},
            
            f'../results/{DESC}/metadata.pth')

# %% [markdown]
# # training curves

# %%
# plot training curves
import matplotlib.pyplot as plt

# losses
plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train')
plt.plot(val_losses, label='Val')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# accuracies
plt.subplot(1, 2, 2)
plt.plot(train_accs, label='Train')
plt.plot(val_accs, label='Val')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.savefig(f'../results/{DESC}/training_curves_{EPOCHS}epochs.png')
plt.show()

# %% [markdown]
# # confusion matrix

# %%
# test set results (~15min/1s if images are loaded/not loaded in memory)
resnet.eval()

y_true = []
y_logit = []
y_pred = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_loader):
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        outputs = resnet(inputs)
        y_true.extend(labels.cpu().numpy())
        y_logit.extend(outputs.cpu().numpy())
        y_pred.extend(torch.softmax(outputs, dim=1).argmax(dim=1).cpu().numpy())

y_true = np.array(y_true)
y_logit = np.array(y_logit)
y_pred = np.array(y_pred)
np.savez(f'../results/{DESC}/test_results.npz', y_true=y_true, y_logit=y_logit, y_pred=y_pred)

# %%
# TODO: clean this up

'''
CLASSIFICATION REPORT AND CONFUSIONMATRIXDISPLAY
'''
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix
print(classification_report(y_true, y_pred, labels=range(NUM_CLASSES), target_names=LABELS_MAP, zero_division=0))

cm = 100*confusion_matrix(y_true, y_pred, labels=range(NUM_CLASSES), normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=LABELS_MAP)
# plot on large figure
fig, ax = plt.subplots(figsize=(20,20))
disp.plot(xticks_rotation = 45, values_format = '.2f', ax=ax, cmap='Blues')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

'''
SIMPLE CONFUSION MATRIX
'''
# confusion matrix for test set
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns

# simple
cm = 100*confusion_matrix(y_true, y_pred, labels=range(NUM_CLASSES), normalize='true')
plt.figure(figsize=(20, 15))
sns.heatmap(cm, annot=True, cmap='Blues',
            xticklabels=LABELS_MAP,
            yticklabels=LABELS_MAP)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

'''
CLEARER CONFUSION MATRIX (saved)
'''
# Compute normalized confusion matrix (row-wise normalization)
cm = confusion_matrix(y_true, y_pred, labels=range(NUM_CLASSES), normalize='true')

# Convert to integer percentages (whole numbers for clarity)
cm_percent = (cm * 100).astype(int)

# Get the number of true labels per class
true_counts = np.bincount(y_true, minlength=NUM_CLASSES)

# Create annotation labels: format as integer percentages, hide 0%
annot_labels = np.empty_like(cm_percent, dtype=object)
for i in range(cm_percent.shape[0]):
    for j in range(cm_percent.shape[1]):
        if cm_percent[i, j] > 0:
            annot_labels[i, j] = f"{cm_percent[i, j]}%"  # No decimals
        else:
            annot_labels[i, j] = ""

# Modify y-tick labels to include true label counts
class_labels = LABELS_MAP
yticklabels_with_counts = [f"{label} ({true_counts[i]})" for i, label in enumerate(class_labels)]

# Plot the heatmap in YOLO style
plt.figure(figsize=(12, 10))  # Adjust figure size for readability
sns.heatmap(cm_percent, annot=annot_labels, fmt='', cmap='Blues',
            xticklabels=class_labels,
            yticklabels=yticklabels_with_counts,  # Updated y-tick labels
            linewidths=0.5, linecolor='gray', square=True, cbar=False)  # Clean grid layout

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix, Overall Accuracy: {100*correct/test_N:.2f}%')
plt.tight_layout()
plt.savefig(f'../results/{DESC}/confusion_matrix_{EPOCHS}epochs.png')
plt.show()
# Out:
#                     precision    recall  f1-score   support
#
#            0-No DR       0.82      0.94      0.88      5162
#             1-Mild       0.00      0.00      0.00       489
#         2-Moderate       0.49      0.37      0.42      1059
#           3-Severe       0.40      0.39      0.40       175
# 4-Proliferative DR       0.53      0.51      0.52       141
#
#           accuracy                           0.77      7026
#          macro avg       0.45      0.44      0.44      7026
#       weighted avg       0.70      0.77      0.73      7026
