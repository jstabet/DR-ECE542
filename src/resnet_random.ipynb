# %% [raw]
# # build dataset
#
# TODO:
# * train on whole dataset (preprocess images first since it will take too long) --> DONE
# * remove random split and split data beforehand --> split data so as to counteract class imbalance. Moderate imbalance so use SMOTE (oversampling)

# %%
import os
import pandas as pd
import torch
from torchvision import models
from utils import DRDataset
from sklearn.model_selection import train_test_split
import numpy as np

DESC = 'resnet_random'
if not os.path.exists(f'../results/{DESC}'):
    os.makedirs(f'../results/{DESC}')
    
#load labels
labels = pd.read_csv('../data/trainLabels.csv')

NUM_CLASSES = len(labels['level'].unique())
LABELS_MAP = ['0-No DR', '1-Mild', '2-Moderate', '3-Severe', '4-Proliferative DR']
BATCH_SIZE = 32

# split into train/val/test (70/10/20)
# TODO --> use torch to split all at once?
labels_train, labels_test = train_test_split(labels, test_size=0.3, random_state=42)
labels_val, labels_test = train_test_split(labels_test, test_size=2/3, random_state=42)

# Create dataset objects using the resampled labels
train_data = DRDataset(labels_train, '../data/preproc_train_imgs.pt',
                       preproc=models.ResNet50_Weights.DEFAULT.transforms())
val_data = DRDataset(labels_val, '../data/preproc_train_imgs.pt',
                     preproc=models.ResNet50_Weights.DEFAULT.transforms())
test_data = DRDataset(labels_test, '../data/preproc_train_imgs.pt',
                      preproc=models.ResNet50_Weights.DEFAULT.transforms())


#Create DataLoaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

#dataset size checks
train_N = len(train_loader.dataset)
val_N = len(val_loader.dataset)
test_N = len(test_loader.dataset)

train_N, val_N, test_N
# Out:
# (24588, 3512, 7026)

# %% [raw]
# # build model
#
# TODO:
# * more dense layers?
# * different backbone (other than resnet)? Can change this for the project to include a hybrid CNN/Transformer model depending on if we want or need greater generalization, etc.
# * can create weighted loss function
# * can add class weights if SMOTE doesn't yield good results

# %%
# load resnet
resnet = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
# freeze weights
resnet.requires_grad_(False)
# adjust last layer for binary classification
resnet.fc = torch.nn.Linear(resnet.fc.in_features, NUM_CLASSES)
resnet.fc.requires_grad_(True)

# print model summary
from torchinfo import summary
summary(resnet, input_size=next(resnet.parameters()).size())
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [64, 5]                   --
# ├─Conv2d: 1-1                            [64, 64, 4, 4]            (9,408)
# ├─BatchNorm2d: 1-2                       [64, 64, 4, 4]            (128)
# ├─ReLU: 1-3                              [64, 64, 4, 4]            --
# ├─MaxPool2d: 1-4                         [64, 64, 2, 2]            --
# ├─Sequential: 1-5                        [64, 256, 2, 2]           --
# │    └─Bottleneck: 2-1                   [64, 256, 2, 2]           --
# │    │    └─Conv2d: 3-1                  [64, 64, 2, 2]            (4,096)
# │    │    └─BatchNorm2d: 3-2             [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-3                    [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-4                  [64, 64, 2, 2]            (36,864)
# │    │    └─BatchNorm2d: 3-5             [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-6                    [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-7                  [64, 256, 2, 2]           (16,384)
# │    │    └─BatchNorm2d: 3-8             [64, 256, 2, 2]           (512)
# │    │    └─Sequential: 3-9              [64, 256, 2, 2]           (16,896)
# │    │    └─ReLU: 3-10                   [64, 256, 2, 2]           --
# │    └─Bottleneck: 2-2                   [64, 256, 2, 2]           --
# │    │    └─Conv2d: 3-11                 [64, 64, 2, 2]            (16,384)
# │    │    └─BatchNorm2d: 3-12            [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-13                   [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-14                 [64, 64, 2, 2]            (36,864)
# │    │    └─BatchNorm2d: 3-15            [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-16                   [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-17                 [64, 256, 2, 2]           (16,384)
# │    │    └─BatchNorm2d: 3-18            [64, 256, 2, 2]           (512)
# │    │    └─ReLU: 3-19                   [64, 256, 2, 2]           --
# │    └─Bottleneck: 2-3                   [64, 256, 2, 2]           --
# │    │    └─Conv2d: 3-20                 [64, 64, 2, 2]            (16,384)
# │    │    └─BatchNorm2d: 3-21            [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-22                   [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-23                 [64, 64, 2, 2]            (36,864)
# │    │    └─BatchNorm2d: 3-24            [64, 64, 2, 2]            (128)
# │    │    └─ReLU: 3-25                   [64, 64, 2, 2]            --
# │    │    └─Conv2d: 3-26                 [64, 256, 2, 2]           (16,384)
# │    │    └─BatchNorm2d: 3-27            [64, 256, 2, 2]           (512)
# │    │    └─ReLU: 3-28                   [64, 256, 2, 2]           --
# ├─Sequential: 1-6                        [64, 512, 1, 1]           --
# │    └─Bottleneck: 2-4                   [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-29                 [64, 128, 2, 2]           (32,768)
# │    │    └─BatchNorm2d: 3-30            [64, 128, 2, 2]           (256)
# │    │    └─ReLU: 3-31                   [64, 128, 2, 2]           --
# │    │    └─Conv2d: 3-32                 [64, 128, 1, 1]           (147,456)
# │    │    └─BatchNorm2d: 3-33            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-34                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-35                 [64, 512, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-36            [64, 512, 1, 1]           (1,024)
# │    │    └─Sequential: 3-37             [64, 512, 1, 1]           (132,096)
# │    │    └─ReLU: 3-38                   [64, 512, 1, 1]           --
# │    └─Bottleneck: 2-5                   [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-39                 [64, 128, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-40            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-41                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-42                 [64, 128, 1, 1]           (147,456)
# │    │    └─BatchNorm2d: 3-43            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-44                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-45                 [64, 512, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-46            [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-47                   [64, 512, 1, 1]           --
# │    └─Bottleneck: 2-6                   [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-48                 [64, 128, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-49            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-50                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-51                 [64, 128, 1, 1]           (147,456)
# │    │    └─BatchNorm2d: 3-52            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-53                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-54                 [64, 512, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-55            [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-56                   [64, 512, 1, 1]           --
# │    └─Bottleneck: 2-7                   [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-57                 [64, 128, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-58            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-59                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-60                 [64, 128, 1, 1]           (147,456)
# │    │    └─BatchNorm2d: 3-61            [64, 128, 1, 1]           (256)
# │    │    └─ReLU: 3-62                   [64, 128, 1, 1]           --
# │    │    └─Conv2d: 3-63                 [64, 512, 1, 1]           (65,536)
# │    │    └─BatchNorm2d: 3-64            [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-65                   [64, 512, 1, 1]           --
# ├─Sequential: 1-7                        [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-8                   [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-66                 [64, 256, 1, 1]           (131,072)
# │    │    └─BatchNorm2d: 3-67            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-68                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-69                 [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-70            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-71                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-72                 [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-73            [64, 1024, 1, 1]          (2,048)
# │    │    └─Sequential: 3-74             [64, 1024, 1, 1]          (526,336)
# │    │    └─ReLU: 3-75                   [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-9                   [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-76                 [64, 256, 1, 1]           (262,144)
# │    │    └─BatchNorm2d: 3-77            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-78                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-79                 [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-80            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-81                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-82                 [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-83            [64, 1024, 1, 1]          (2,048)
# │    │    └─ReLU: 3-84                   [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-10                  [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-85                 [64, 256, 1, 1]           (262,144)
# │    │    └─BatchNorm2d: 3-86            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-87                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-88                 [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-89            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-90                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-91                 [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-92            [64, 1024, 1, 1]          (2,048)
# │    │    └─ReLU: 3-93                   [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-11                  [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-94                 [64, 256, 1, 1]           (262,144)
# │    │    └─BatchNorm2d: 3-95            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-96                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-97                 [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-98            [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-99                   [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-100                [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-101           [64, 1024, 1, 1]          (2,048)
# │    │    └─ReLU: 3-102                  [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-12                  [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-103                [64, 256, 1, 1]           (262,144)
# │    │    └─BatchNorm2d: 3-104           [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-105                  [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-106                [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-107           [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-108                  [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-109                [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-110           [64, 1024, 1, 1]          (2,048)
# │    │    └─ReLU: 3-111                  [64, 1024, 1, 1]          --
# │    └─Bottleneck: 2-13                  [64, 1024, 1, 1]          --
# │    │    └─Conv2d: 3-112                [64, 256, 1, 1]           (262,144)
# │    │    └─BatchNorm2d: 3-113           [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-114                  [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-115                [64, 256, 1, 1]           (589,824)
# │    │    └─BatchNorm2d: 3-116           [64, 256, 1, 1]           (512)
# │    │    └─ReLU: 3-117                  [64, 256, 1, 1]           --
# │    │    └─Conv2d: 3-118                [64, 1024, 1, 1]          (262,144)
# │    │    └─BatchNorm2d: 3-119           [64, 1024, 1, 1]          (2,048)
# │    │    └─ReLU: 3-120                  [64, 1024, 1, 1]          --
# ├─Sequential: 1-8                        [64, 2048, 1, 1]          --
# │    └─Bottleneck: 2-14                  [64, 2048, 1, 1]          --
# │    │    └─Conv2d: 3-121                [64, 512, 1, 1]           (524,288)
# │    │    └─BatchNorm2d: 3-122           [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-123                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-124                [64, 512, 1, 1]           (2,359,296)
# │    │    └─BatchNorm2d: 3-125           [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-126                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-127                [64, 2048, 1, 1]          (1,048,576)
# │    │    └─BatchNorm2d: 3-128           [64, 2048, 1, 1]          (4,096)
# │    │    └─Sequential: 3-129            [64, 2048, 1, 1]          (2,101,248)
# │    │    └─ReLU: 3-130                  [64, 2048, 1, 1]          --
# │    └─Bottleneck: 2-15                  [64, 2048, 1, 1]          --
# │    │    └─Conv2d: 3-131                [64, 512, 1, 1]           (1,048,576)
# │    │    └─BatchNorm2d: 3-132           [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-133                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-134                [64, 512, 1, 1]           (2,359,296)
# │    │    └─BatchNorm2d: 3-135           [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-136                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-137                [64, 2048, 1, 1]          (1,048,576)
# │    │    └─BatchNorm2d: 3-138           [64, 2048, 1, 1]          (4,096)
# │    │    └─ReLU: 3-139                  [64, 2048, 1, 1]          --
# │    └─Bottleneck: 2-16                  [64, 2048, 1, 1]          --
# │    │    └─Conv2d: 3-140                [64, 512, 1, 1]           (1,048,576)
# │    │    └─BatchNorm2d: 3-141           [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-142                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-143                [64, 512, 1, 1]           (2,359,296)
# │    │    └─BatchNorm2d: 3-144           [64, 512, 1, 1]           (1,024)
# │    │    └─ReLU: 3-145                  [64, 512, 1, 1]           --
# │    │    └─Conv2d: 3-146                [64, 2048, 1, 1]          (1,048,576)
# │    │    └─BatchNorm2d: 3-147           [64, 2048, 1, 1]          (4,096)
# │    │    └─ReLU: 3-148                  [64, 2048, 1, 1]          --
# ├─AdaptiveAvgPool2d: 1-9                 [64, 2048, 1, 1]          --
# ├─Linear: 1-10                           [64, 5]                   10,245
# ==========================================================================================
# Total params: 23,518,277
# Trainable params: 10,245
# Non-trainable params: 23,508,032
# Total mult-adds (Units.GIGABYTES): 1.56
# ==========================================================================================
# Input size (MB): 0.04
# Forward/backward pass size (MB): 32.90
# Params size (MB): 94.07
# Estimated Total Size (MB): 127.01
# ==========================================================================================

# %% [raw]
# # train/val/test
#
# TODO:
# * early stopping?
# * potentially modify loss function after assessing baseline

# %%
# compile model
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
resnet.to(DEVICE)
loss_fn = torch.nn.CrossEntropyLoss() # expects logits
optimizer = torch.optim.Adam(resnet.parameters())

# train
EPOCHS = 100
train_losses = []
val_losses = []
train_accs = []
val_accs = []
best_val_loss = torch.inf
for epoch in range(EPOCHS):
    # train
    resnet.train()
    running_loss = 0.0
    running_correct = 0
    for i, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = resnet(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        running_correct += (torch.softmax(outputs, dim=1).argmax(dim=1) == labels).sum().item()

    # val
    resnet.eval()
    running_vloss = 0.0
    running_vcorrect = 0
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_loader):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

            outputs = resnet(inputs)
            vloss = loss_fn(outputs, labels)
            running_vloss += vloss.item()
            running_vcorrect += (torch.softmax(outputs, dim=1).argmax(dim=1) == labels).sum().item()

    print(f"Epoch {epoch+1}/{EPOCHS}\t" +
          f"Train Loss: {running_loss/train_N:.4f} | Train Acc: {running_correct/train_N:.4f} | " +
          f"Val Loss: {running_vloss/val_N:.4f} | Val Acc: {running_vcorrect/val_N:.4f}")

    train_losses.append(running_loss/train_N)
    val_losses.append(running_vloss/val_N)
    train_accs.append(running_correct/train_N)
    val_accs.append(running_vcorrect/val_N)

    # save best model
    if running_vloss < best_val_loss:
        best_val_loss = running_vloss
        torch.save(resnet, f'../results/{DESC}/model.pth')

# evaluate
# load best model
resnet = torch.load(f'../results/{DESC}/model.pth', weights_only=False).to(DEVICE)
resnet.eval()
correct = 0
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_loader):
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        outputs = resnet(inputs)
        correct += (torch.softmax(outputs, dim=1).argmax(dim=1) == labels).sum().item()
print()
print(f'Test Accuracy: {correct/test_N:.4f}')
# Out:
# Epoch 1/100	Train Loss: 0.0256 | Train Acc: 0.7367 | Val Loss: 0.0239 | Val Acc: 0.7480
# Epoch 2/100	Train Loss: 0.0234 | Train Acc: 0.7468 | Val Loss: 0.0237 | Val Acc: 0.7497
# Epoch 3/100	Train Loss: 0.0228 | Train Acc: 0.7503 | Val Loss: 0.0234 | Val Acc: 0.7514
# Epoch 4/100	Train Loss: 0.0223 | Train Acc: 0.7522 | Val Loss: 0.0233 | Val Acc: 0.7528
# Epoch 5/100	Train Loss: 0.0220 | Train Acc: 0.7576 | Val Loss: 0.0233 | Val Acc: 0.7511
# Epoch 6/100	Train Loss: 0.0217 | Train Acc: 0.7596 | Val Loss: 0.0232 | Val Acc: 0.7511
# Epoch 7/100	Train Loss: 0.0214 | Train Acc: 0.7610 | Val Loss: 0.0232 | Val Acc: 0.7526
# Epoch 8/100	Train Loss: 0.0212 | Train Acc: 0.7626 | Val Loss: 0.0231 | Val Acc: 0.7517
# Epoch 9/100	Train Loss: 0.0210 | Train Acc: 0.7624 | Val Loss: 0.0231 | Val Acc: 0.7511
# Epoch 10/100	Train Loss: 0.0210 | Train Acc: 0.7613 | Val Loss: 0.0234 | Val Acc: 0.7520
# Epoch 11/100	Train Loss: 0.0209 | Train Acc: 0.7639 | Val Loss: 0.0233 | Val Acc: 0.7528
# Epoch 12/100	Train Loss: 0.0208 | Train Acc: 0.7668 | Val Loss: 0.0236 | Val Acc: 0.7534
# Epoch 13/100	Train Loss: 0.0208 | Train Acc: 0.7642 | Val Loss: 0.0237 | Val Acc: 0.7540
# Epoch 14/100	Train Loss: 0.0208 | Train Acc: 0.7648 | Val Loss: 0.0238 | Val Acc: 0.7531
# Epoch 15/100	Train Loss: 0.0204 | Train Acc: 0.7679 | Val Loss: 0.0238 | Val Acc: 0.7514
# Epoch 16/100	Train Loss: 0.0206 | Train Acc: 0.7674 | Val Loss: 0.0236 | Val Acc: 0.7514
# Epoch 17/100	Train Loss: 0.0205 | Train Acc: 0.7672 | Val Loss: 0.0236 | Val Acc: 0.7531
# Epoch 18/100	Train Loss: 0.0205 | Train Acc: 0.7669 | Val Loss: 0.0238 | Val Acc: 0.7503
# Epoch 19/100	Train Loss: 0.0205 | Train Acc: 0.7683 | Val Loss: 0.0238 | Val Acc: 0.7580
# Epoch 20/100	Train Loss: 0.0203 | Train Acc: 0.7687 | Val Loss: 0.0239 | Val Acc: 0.7415
# Epoch 21/100	Train Loss: 0.0203 | Train Acc: 0.7685 | Val Loss: 0.0241 | Val Acc: 0.7503
# Epoch 22/100	Train Loss: 0.0202 | Train Acc: 0.7690 | Val Loss: 0.0240 | Val Acc: 0.7494
# %%
# save datasets, optimizer state, and metrics to metadata file
torch.save({'train_data': train_data,
            'val_data': val_data,
            'test_data': test_data,
            'optimizer_state': optimizer.state_dict(),
            'metrics': pd.DataFrame({'train_loss': train_losses,
                                     'val_loss': val_losses,
                                     'train_acc': train_accs,
                                     'val_acc': val_accs})},
            
            f'../results/{DESC}/metadata.pth')

# %% [markdown]
# # training curves

# %%
# plot training curves
import matplotlib.pyplot as plt

# losses
plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train')
plt.plot(val_losses, label='Val')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# accuracies
plt.subplot(1, 2, 2)
plt.plot(train_accs, label='Train')
plt.plot(val_accs, label='Val')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.savefig(f'../results/{DESC}/training_curves_{EPOCHS}epochs.png')
plt.show()

# %% [markdown]
# # confusion matrix

# %%
# test set results (~15min/1s if images are loaded/not loaded in memory)
resnet.eval()
y_true = []
y_pred = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_loader):
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        outputs = resnet(inputs)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(torch.softmax(outputs, dim=1).argmax(dim=1).cpu().numpy())

y_true = np.array(y_true)
y_pred = np.array(y_pred)
np.savez(f'../results/{DESC}/test_results.npz', y_true=y_true, y_pred=y_pred)

# %%
# TODO: clean this up

'''
CLASSIFICATION REPORT AND CONFUSIONMATRIXDISPLAY
'''
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix
print(classification_report(y_true, y_pred, labels=range(NUM_CLASSES), target_names=LABELS_MAP, zero_division=0))

cm = 100*confusion_matrix(y_true, y_pred, labels=range(NUM_CLASSES), normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=LABELS_MAP)
# plot on large figure
fig, ax = plt.subplots(figsize=(20,20))
disp.plot(xticks_rotation = 45, values_format = '.2f', ax=ax, cmap='Blues')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

'''
SIMPLE CONFUSION MATRIX
'''
# confusion matrix for test set
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns

# simple
cm = 100*confusion_matrix(y_true, y_pred, labels=range(NUM_CLASSES), normalize='true')
plt.figure(figsize=(20, 15))
sns.heatmap(cm, annot=True, cmap='Blues',
            xticklabels=LABELS_MAP,
            yticklabels=LABELS_MAP)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

'''
CLEARER CONFUSION MATRIX (saved)
'''
# Compute normalized confusion matrix (row-wise normalization)
cm = confusion_matrix(y_true, y_pred, labels=range(NUM_CLASSES), normalize='true')

# Convert to integer percentages (whole numbers for clarity)
cm_percent = (cm * 100).astype(int)

# Get the number of true labels per class
true_counts = np.bincount(y_true, minlength=NUM_CLASSES)

# Create annotation labels: format as integer percentages, hide 0%
annot_labels = np.empty_like(cm_percent, dtype=object)
for i in range(cm_percent.shape[0]):
    for j in range(cm_percent.shape[1]):
        if cm_percent[i, j] > 0:
            annot_labels[i, j] = f"{cm_percent[i, j]}%"  # No decimals
        else:
            annot_labels[i, j] = ""

# Modify y-tick labels to include true label counts
class_labels = LABELS_MAP
yticklabels_with_counts = [f"{label} ({true_counts[i]})" for i, label in enumerate(class_labels)]

# Plot the heatmap in YOLO style
plt.figure(figsize=(12, 10))  # Adjust figure size for readability
sns.heatmap(cm_percent, annot=annot_labels, fmt='', cmap='Blues',
            xticklabels=class_labels,
            yticklabels=yticklabels_with_counts,  # Updated y-tick labels
            linewidths=0.5, linecolor='gray', square=True, cbar=False)  # Clean grid layout

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix, Overall Accuracy: {100*correct/test_N:.2f}%')
plt.tight_layout()
plt.savefig(f'../results/{DESC}/confusion_matrix_{EPOCHS}epochs.png')
plt.show()
# Out:
#                     precision    recall  f1-score   support
#
#            0-No DR       0.78      0.97      0.87      5174
#             1-Mild       0.19      0.01      0.01       476
#         2-Moderate       0.45      0.18      0.26      1075
#           3-Severe       0.28      0.09      0.14       162
# 4-Proliferative DR       0.51      0.30      0.38       139
#
#           accuracy                           0.75      7026
#          macro avg       0.44      0.31      0.33      7026
#       weighted avg       0.67      0.75      0.69      7026
